# %% [markdown]
# ### CNN on CIFR implementing Dense net research paper:

# %%
from tensorflow.keras import models, layers
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import BatchNormalization, Activation, Flatten
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import os
from keras.callbacks import ModelCheckpoint

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir('drive/MyDrive')

# %%
# Hyperparameters
num_classes = 10
weight_decay = 1e-4
num_filter = 12
compression = 0.5

# %%
# Load CIFAR10 Data
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()
img_height, img_width, channel = X_train.shape[1],X_train.shape[2],X_train.shape[3]

# convert to one hot encoing 
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %%
#Image augmentation
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    width_shift_range = 0.3,
    height_shift_range = 0.3,
    horizontal_flip=True,
    rotation_range=30
)
validation_datagen = ImageDataGenerator(
    rescale = 1./255,
    width_shift_range = 0.2,
    height_shift_range = 0.2
)

train_datagenerator = train_datagen.flow(
    X_train,y_train,
    batch_size=64,
    seed = 56
)

validation_datagenerator = validation_datagen.flow(
    X_test,y_test,
    batch_size=64,
    seed = 56
)

# %%
# Dense Block
def denseblock1(input, num_filter = 12, dropout_rate = 0):
    global compression
    temp = input
    for _ in range(l): 
        BatchNorm = layers.BatchNormalization()(temp)
        relu = layers.Activation('relu')(BatchNorm)
        Conv2D_3_3 = layers.Conv2D(int(num_filter*compression), (3,3), use_bias=False ,padding='same',kernel_initializer="he_uniform")(relu)
        if dropout_rate>0:
            Conv2D_3_3 = layers.Dropout(dropout_rate)(Conv2D_3_3)
        concat = layers.Concatenate(axis=-1)([temp,Conv2D_3_3])
        
        temp = concat
        
    return temp

## transition Blosck
def transition1(input, num_filter = 12, dropout_rate = 0):
    global compression
    BatchNorm = layers.BatchNormalization()(input)
    relu = layers.Activation('relu')(BatchNorm)
    Conv2D_BottleNeck = layers.Conv2D(int(num_filter*compression), (3,3), use_bias=False ,padding='same',kernel_initializer="he_uniform")(relu)
    if dropout_rate>0:
         Conv2D_BottleNeck = layers.Dropout(dropout_rate)(Conv2D_BottleNeck)
    avg = layers.AveragePooling2D(pool_size=(2,2))(Conv2D_BottleNeck)
    return avg

#output layer
def output_layer1(input):
    global compression
    BatchNorm = layers.BatchNormalization()(input)
    relu = layers.Activation('relu')(BatchNorm)
    AvgPooling = layers.AveragePooling2D(pool_size=(2,2))(relu)
    flat = layers.Flatten()(AvgPooling)
    output = layers.Dense(num_classes, activation='softmax')(flat)
    return output

num_filter = 60
l = 6
tf.keras.backend.clear_session()

input = layers.Input(shape=(img_height, img_width, channel,))
First_Conv2D = layers.Conv2D(num_filter, (3,3), use_bias=False ,padding='same')(input)

First_Block = denseblock1(First_Conv2D, num_filter)
First_Transition = transition1(First_Block, num_filter)

Second_Block = denseblock1(First_Transition, num_filter)
Second_Transition = transition1(Second_Block, num_filter)

Third_Block = denseblock1(Second_Transition, num_filter)
Third_Transition = transition1(Third_Block, num_filter)

Last_Block = denseblock1(Third_Transition,  num_filter)
output = output_layer1(Last_Block)

model1 = Model(inputs=[input], outputs=[output])
model1.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 60)   1620        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 60)   240         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 60)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 30)   16200       activation[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 90)   0           conv2d[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 90)   360         concatenate[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 90)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 30)   24300       activation_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 120)  0           concatenate[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 120)  480         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 120)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 30)   32400       activation_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 150)  0           concatenate_1[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 150)  600         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 150)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 30)   40500       activation_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 32, 32, 180)  0           concatenate_2[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 180)  720         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 180)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 30)   48600       activation_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 210)  0           concatenate_3[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 210)  840         concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 210)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 30)   56700       activation_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 32, 32, 240)  0           concatenate_4[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 240)  960         concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 240)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 30)   64800       activation_6[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 16, 16, 30)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 30)   120         average_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 30)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 30)   8100        activation_7[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 16, 16, 60)   0           average_pooling2d[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 60)   240         concatenate_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 60)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 30)   16200       activation_8[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 16, 16, 90)   0           concatenate_6[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 90)   360         concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 90)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 30)   24300       activation_9[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 16, 16, 120)  0           concatenate_7[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 120)  480         concatenate_8[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 120)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 30)   32400       activation_10[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 16, 16, 150)  0           concatenate_8[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 150)  600         concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 150)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 30)   40500       activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 16, 16, 180)  0           concatenate_9[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 180)  720         concatenate_10[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 180)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 30)   48600       activation_12[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 16, 16, 210)  0           concatenate_10[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 210)  840         concatenate_11[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 210)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 30)   56700       activation_13[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 8, 8, 30)     0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 30)     120         average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 30)     0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 30)     8100        activation_14[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 8, 8, 60)     0           average_pooling2d_1[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 60)     240         concatenate_12[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 60)     0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 30)     16200       activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 8, 8, 90)     0           concatenate_12[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 90)     360         concatenate_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 90)     0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 30)     24300       activation_16[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 8, 8, 120)    0           concatenate_13[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 8, 120)    480         concatenate_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 120)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 30)     32400       activation_17[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 8, 8, 150)    0           concatenate_14[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 8, 8, 150)    600         concatenate_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 150)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 30)     40500       activation_18[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 8, 8, 180)    0           concatenate_15[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 8, 8, 180)    720         concatenate_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 8, 8, 180)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 30)     48600       activation_19[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 8, 8, 210)    0           concatenate_16[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 8, 8, 210)    840         concatenate_17[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 8, 8, 210)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 30)     56700       activation_20[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 4, 4, 30)     0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 4, 4, 30)     120         average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 4, 4, 30)     0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 4, 4, 30)     8100        activation_21[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 4, 4, 60)     0           average_pooling2d_2[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 4, 4, 60)     240         concatenate_18[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 4, 4, 60)     0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 4, 4, 30)     16200       activation_22[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 4, 4, 90)     0           concatenate_18[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 4, 4, 90)     360         concatenate_19[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 4, 4, 90)     0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 4, 4, 30)     24300       activation_23[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 4, 4, 120)    0           concatenate_19[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 4, 4, 120)    480         concatenate_20[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 4, 4, 120)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 4, 4, 30)     32400       activation_24[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 4, 4, 150)    0           concatenate_20[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 4, 4, 150)    600         concatenate_21[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 4, 4, 150)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 4, 4, 30)     40500       activation_25[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 4, 4, 180)    0           concatenate_21[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 4, 4, 180)    720         concatenate_22[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 4, 4, 180)    0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 4, 4, 30)     48600       activation_26[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 4, 4, 210)    0           concatenate_22[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 4, 4, 210)    840         concatenate_23[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 4, 4, 210)    0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 2, 2, 210)    0           activation_27[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 840)          0           average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           8410        flatten[0][0]
# ==================================================================================================
# Total params: 931,510
# Trainable params: 924,370
# Non-trainable params: 7,140
# __________________________________________________________________________________________________

# %%
# callbacks
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self,epoch,logs={}):
    if ((logs.get('accuracy')-logs.get('val_accuracy')>0.03) and logs.get('val_accuracy')>0.90) or logs.get('val_accuracy')>0.91:
      print("\nOverfitting begins....terminating the training")
      self.model.stop_training=True

overfitting_callback = myCallback()
filepath1 = 'checkpoint_weights/weights.h5'
checkpoint = ModelCheckpoint(filepath1, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
def scheduler(epoch, lr):
  if epoch%25==0:
    return lr/3
  else:
    return lr
callback_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

# %%
# determine Loss function and Optimizer
model1.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

history1 = model1.fit(train_datagenerator,
          batch_size=64,
          epochs=300,
          verbose=1, 
          validation_data=validation_datagenerator,
          callbacks = [overfitting_callback,checkpoint,callback_scheduler])
# Out:
# Epoch 1/300
#   6/782 [..............................] - ETA: 1:03 - loss: 2.4108 - accuracy: 0.1224WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0393s vs `on_train_batch_end` time: 0.0441s). Check your callbacks.
# 782/782 [==============================] - 66s 82ms/step - loss: 1.6547 - accuracy: 0.3913 - val_loss: 1.7054 - val_accuracy: 0.4234
#
# Epoch 00001: val_accuracy improved from -inf to 0.42340, saving model to checkpoint_weights/weights.h5
# Epoch 2/300
# 782/782 [==============================] - 63s 80ms/step - loss: 1.2939 - accuracy: 0.5366 - val_loss: 1.4108 - val_accuracy: 0.5098
#
# Epoch 00002: val_accuracy improved from 0.42340 to 0.50980, saving model to checkpoint_weights/weights.h5
# Epoch 3/300
# 782/782 [==============================] - 63s 80ms/step - loss: 1.1061 - accuracy: 0.6068 - val_loss: 1.0961 - val_accuracy: 0.6147
#
# Epoch 00003: val_accuracy improved from 0.50980 to 0.61470, saving model to checkpoint_weights/weights.h5
# Epoch 4/300
# 782/782 [==============================] - 63s 80ms/step - loss: 0.9967 - accuracy: 0.6492 - val_loss: 1.0223 - val_accuracy: 0.6440
#
# Epoch 00004: val_accuracy improved from 0.61470 to 0.64400, saving model to checkpoint_weights/weights.h5
# Epoch 5/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.9121 - accuracy: 0.6766 - val_loss: 0.8607 - val_accuracy: 0.6993
#
# Epoch 00005: val_accuracy improved from 0.64400 to 0.69930, saving model to checkpoint_weights/weights.h5
# Epoch 6/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.8517 - accuracy: 0.7013 - val_loss: 1.0373 - val_accuracy: 0.6529
#
# Epoch 00006: val_accuracy did not improve from 0.69930
# Epoch 7/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.7976 - accuracy: 0.7237 - val_loss: 1.0056 - val_accuracy: 0.6700
#
# Epoch 00007: val_accuracy did not improve from 0.69930
# Epoch 8/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.7552 - accuracy: 0.7362 - val_loss: 1.2480 - val_accuracy: 0.6266
#
# Epoch 00008: val_accuracy did not improve from 0.69930
# Epoch 9/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.7213 - accuracy: 0.7497 - val_loss: 0.7606 - val_accuracy: 0.7438
#
# Epoch 00009: val_accuracy improved from 0.69930 to 0.74380, saving model to checkpoint_weights/weights.h5
# Epoch 10/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.6883 - accuracy: 0.7617 - val_loss: 0.8305 - val_accuracy: 0.7180
#
# Epoch 00010: val_accuracy did not improve from 0.74380
# Epoch 11/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.6635 - accuracy: 0.7709 - val_loss: 0.6987 - val_accuracy: 0.7551
#
# Epoch 00011: val_accuracy improved from 0.74380 to 0.75510, saving model to checkpoint_weights/weights.h5
# Epoch 12/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.6331 - accuracy: 0.7800 - val_loss: 0.7942 - val_accuracy: 0.7329
#
# Epoch 00012: val_accuracy did not improve from 0.75510
# Epoch 13/300
# 782/782 [==============================] - 63s 80ms/step - loss: 0.6185 - accuracy: 0.7845 - val_loss: 0.7359 - val_accuracy: 0.7512
#
# Epoch 00013: val_accuracy did not improve from 0.75510
# Epoch 14/300
# 782/782 [==============================] - 63s 80ms/step - loss: 0.5971 - accuracy: 0.7929 - val_loss: 0.6642 - val_accuracy: 0.7717
#
# Epoch 00014: val_accuracy improved from 0.75510 to 0.77170, saving model to checkpoint_weights/weights.h5
# Epoch 15/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.5758 - accuracy: 0.8005 - val_loss: 0.5777 - val_accuracy: 0.8007
#
# Epoch 00015: val_accuracy improved from 0.77170 to 0.80070, saving model to checkpoint_weights/weights.h5
# Epoch 16/300
# 782/782 [==============================] - 63s 80ms/step - loss: 0.5597 - accuracy: 0.8058 - val_loss: 0.5616 - val_accuracy: 0.8072
#
# Epoch 00016: val_accuracy improved from 0.80070 to 0.80720, saving model to checkpoint_weights/weights.h5
# Epoch 17/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.5479 - accuracy: 0.8099 - val_loss: 0.5564 - val_accuracy: 0.8103
#
# Epoch 00017: val_accuracy improved from 0.80720 to 0.81030, saving model to checkpoint_weights/weights.h5
# Epoch 18/300
# 782/782 [==============================] - 63s 80ms/step - loss: 0.5299 - accuracy: 0.8161 - val_loss: 0.6501 - val_accuracy: 0.7867
#
# Epoch 00018: val_accuracy did not improve from 0.81030
# Epoch 19/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.5215 - accuracy: 0.8205 - val_loss: 0.5864 - val_accuracy: 0.8033
#
# Epoch 00019: val_accuracy did not improve from 0.81030
# Epoch 20/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.5029 - accuracy: 0.8248 - val_loss: 0.6337 - val_accuracy: 0.7890
#
# Epoch 00020: val_accuracy did not improve from 0.81030
# Epoch 21/300
# 782/782 [==============================] - 64s 81ms/step - loss: 0.4956 - accuracy: 0.8295 - val_loss: 0.5343 - val_accuracy: 0.8165
#
# Epoch 00021: val_accuracy improved from 0.81030 to 0.81650, saving model to checkpoint_weights/weights.h5
# Epoch 22/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.4832 - accuracy: 0.8329 - val_loss: 0.4850 - val_accuracy: 0.8380
#
# Epoch 00022: val_accuracy improved from 0.81650 to 0.83800, saving model to checkpoint_weights/weights.h5
# Epoch 23/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.4738 - accuracy: 0.8350 - val_loss: 0.6574 - val_accuracy: 0.7883
#
# Epoch 00023: val_accuracy did not improve from 0.83800
# Epoch 24/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.4647 - accuracy: 0.8386 - val_loss: 0.5436 - val_accuracy: 0.8173
#
# Epoch 00024: val_accuracy did not improve from 0.83800
# Epoch 25/300
# 782/782 [==============================] - 63s 80ms/step - loss: 0.4556 - accuracy: 0.8420 - val_loss: 0.5326 - val_accuracy: 0.8186
#
# Epoch 00025: val_accuracy did not improve from 0.83800
# Epoch 26/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.3881 - accuracy: 0.8656 - val_loss: 0.3697 - val_accuracy: 0.8722
#
# Epoch 00026: val_accuracy improved from 0.83800 to 0.87220, saving model to checkpoint_weights/weights.h5
# Epoch 27/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.3711 - accuracy: 0.8711 - val_loss: 0.3865 - val_accuracy: 0.8675
#
# Epoch 00027: val_accuracy did not improve from 0.87220
# Epoch 28/300
# 782/782 [==============================] - 63s 80ms/step - loss: 0.3619 - accuracy: 0.8756 - val_loss: 0.3787 - val_accuracy: 0.8719
#
# Epoch 00028: val_accuracy did not improve from 0.87220
# Epoch 29/300
# 782/782 [==============================] - 63s 80ms/step - loss: 0.3580 - accuracy: 0.8746 - val_loss: 0.3731 - val_accuracy: 0.8716
#
# Epoch 00029: val_accuracy did not improve from 0.87220
# Epoch 30/300
# 782/782 [==============================] - 63s 80ms/step - loss: 0.3515 - accuracy: 0.8792 - val_loss: 0.3880 - val_accuracy: 0.8700
#
# Epoch 00030: val_accuracy did not improve from 0.87220
# Epoch 31/300
# 782/782 [==============================] - 63s 80ms/step - loss: 0.3455 - accuracy: 0.8809 - val_loss: 0.3469 - val_accuracy: 0.8808
#
# Epoch 00031: val_accuracy improved from 0.87220 to 0.88080, saving model to checkpoint_weights/weights.h5
# Epoch 32/300
# 782/782 [==============================] - 63s 80ms/step - loss: 0.3377 - accuracy: 0.8826 - val_loss: 0.4032 - val_accuracy: 0.8648
#
# Epoch 00032: val_accuracy did not improve from 0.88080
# Epoch 33/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.3375 - accuracy: 0.8819 - val_loss: 0.3519 - val_accuracy: 0.8798
#
# Epoch 00033: val_accuracy did not improve from 0.88080
# Epoch 34/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.3360 - accuracy: 0.8829 - val_loss: 0.3550 - val_accuracy: 0.8830
#
# Epoch 00034: val_accuracy improved from 0.88080 to 0.88300, saving model to checkpoint_weights/weights.h5
# Epoch 35/300
# 782/782 [==============================] - 63s 80ms/step - loss: 0.3278 - accuracy: 0.8865 - val_loss: 0.3718 - val_accuracy: 0.8743
#
# Epoch 00035: val_accuracy did not improve from 0.88300
# Epoch 36/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.3263 - accuracy: 0.8853 - val_loss: 0.3623 - val_accuracy: 0.8779
#
# Epoch 00036: val_accuracy did not improve from 0.88300
# Epoch 37/300
# 782/782 [==============================] - 63s 80ms/step - loss: 0.3226 - accuracy: 0.8866 - val_loss: 0.3667 - val_accuracy: 0.8752
#
# Epoch 00037: val_accuracy did not improve from 0.88300
# Epoch 38/300
# 782/782 [==============================] - 63s 80ms/step - loss: 0.3229 - accuracy: 0.8872 - val_loss: 0.3520 - val_accuracy: 0.8775
#
# Epoch 00038: val_accuracy did not improve from 0.88300
# Epoch 39/300
# 782/782 [==============================] - 63s 80ms/step - loss: 0.3159 - accuracy: 0.8898 - val_loss: 0.3383 - val_accuracy: 0.8827
#
# Epoch 00039: val_accuracy did not improve from 0.88300
# Epoch 40/300
# 782/782 [==============================] - 63s 80ms/step - loss: 0.3134 - accuracy: 0.8910 - val_loss: 0.3630 - val_accuracy: 0.8783
#
# Epoch 00040: val_accuracy did not improve from 0.88300
# Epoch 41/300
# 782/782 [==============================] - 63s 80ms/step - loss: 0.3100 - accuracy: 0.8911 - val_loss: 0.3665 - val_accuracy: 0.8773
#
# Epoch 00041: val_accuracy did not improve from 0.88300
# Epoch 42/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.3105 - accuracy: 0.8926 - val_loss: 0.3399 - val_accuracy: 0.8860
#
# Epoch 00042: val_accuracy improved from 0.88300 to 0.88600, saving model to checkpoint_weights/weights.h5
# Epoch 43/300
# 782/782 [==============================] - 63s 80ms/step - loss: 0.3070 - accuracy: 0.8939 - val_loss: 0.3462 - val_accuracy: 0.8834
#
# Epoch 00043: val_accuracy did not improve from 0.88600
# Epoch 44/300
# 782/782 [==============================] - 63s 80ms/step - loss: 0.3054 - accuracy: 0.8924 - val_loss: 0.3313 - val_accuracy: 0.8875
#
# Epoch 00044: val_accuracy improved from 0.88600 to 0.88750, saving model to checkpoint_weights/weights.h5
# Epoch 45/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.3016 - accuracy: 0.8941 - val_loss: 0.3820 - val_accuracy: 0.8739
#
# Epoch 00045: val_accuracy did not improve from 0.88750
# Epoch 46/300
# 782/782 [==============================] - 63s 80ms/step - loss: 0.2983 - accuracy: 0.8952 - val_loss: 0.3628 - val_accuracy: 0.8796
#
# Epoch 00046: val_accuracy did not improve from 0.88750
# Epoch 47/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.2968 - accuracy: 0.8962 - val_loss: 0.3382 - val_accuracy: 0.8871
#
# Epoch 00047: val_accuracy did not improve from 0.88750
# Epoch 48/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.2970 - accuracy: 0.8971 - val_loss: 0.3492 - val_accuracy: 0.8821
#
# Epoch 00048: val_accuracy did not improve from 0.88750
# Epoch 49/300
# 782/782 [==============================] - 63s 80ms/step - loss: 0.2908 - accuracy: 0.8971 - val_loss: 0.3480 - val_accuracy: 0.8838
#
# Epoch 00049: val_accuracy did not improve from 0.88750
# Epoch 50/300
# 782/782 [==============================] - 63s 80ms/step - loss: 0.2884 - accuracy: 0.8989 - val_loss: 0.3494 - val_accuracy: 0.8820
#
# Epoch 00050: val_accuracy did not improve from 0.88750
# Epoch 51/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.2649 - accuracy: 0.9084 - val_loss: 0.3217 - val_accuracy: 0.8931
#
# Epoch 00051: val_accuracy improved from 0.88750 to 0.89310, saving model to checkpoint_weights/weights.h5
# Epoch 52/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.2566 - accuracy: 0.9089 - val_loss: 0.3114 - val_accuracy: 0.8964
#
# Epoch 00052: val_accuracy improved from 0.89310 to 0.89640, saving model to checkpoint_weights/weights.h5
# Epoch 53/300
# 782/782 [==============================] - 63s 80ms/step - loss: 0.2586 - accuracy: 0.9092 - val_loss: 0.3107 - val_accuracy: 0.8993
#
# Epoch 00053: val_accuracy improved from 0.89640 to 0.89930, saving model to checkpoint_weights/weights.h5
# Epoch 54/300
# 782/782 [==============================] - 63s 80ms/step - loss: 0.2600 - accuracy: 0.9089 - val_loss: 0.3208 - val_accuracy: 0.8961
#
# Epoch 00054: val_accuracy did not improve from 0.89930
# Epoch 55/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.2536 - accuracy: 0.9128 - val_loss: 0.3188 - val_accuracy: 0.8953
#
# Epoch 00055: val_accuracy did not improve from 0.89930
# Epoch 56/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.2500 - accuracy: 0.9131 - val_loss: 0.3132 - val_accuracy: 0.8933
#
# Epoch 00056: val_accuracy did not improve from 0.89930
# Epoch 57/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.2501 - accuracy: 0.9128 - val_loss: 0.3094 - val_accuracy: 0.8991
#
# Epoch 00057: val_accuracy did not improve from 0.89930
# Epoch 58/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.2493 - accuracy: 0.9137 - val_loss: 0.3086 - val_accuracy: 0.8961
#
# Epoch 00058: val_accuracy did not improve from 0.89930
# Epoch 59/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.2503 - accuracy: 0.9121 - val_loss: 0.3059 - val_accuracy: 0.8974
#
# Epoch 00059: val_accuracy did not improve from 0.89930
# Epoch 60/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2469 - accuracy: 0.9125 - val_loss: 0.3095 - val_accuracy: 0.8978
#
# Epoch 00060: val_accuracy did not improve from 0.89930
# Epoch 61/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2444 - accuracy: 0.9144 - val_loss: 0.3133 - val_accuracy: 0.8953
# 782/782 [==============================] - 63s 80ms/step - loss: 0.2479 - accuracy: 0.9135 - val_loss: 0.3122 - val_accuracy: 0.8940
#
# Epoch 00062: val_accuracy did not improve from 0.89930
# Epoch 63/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.2411 - accuracy: 0.9157 - val_loss: 0.3106 - val_accuracy: 0.8970
#
# Epoch 00063: val_accuracy did not improve from 0.89930
# Epoch 64/300
# 782/782 [==============================] - 63s 81ms/step - loss: 0.2416 - accuracy: 0.9157 - val_loss: 0.3229 - val_accuracy: 0.8934
#
# Epoch 00064: val_accuracy did not improve from 0.89930
# Epoch 65/300
# 782/782 [==============================] - 65s 83ms/step - loss: 0.2412 - accuracy: 0.9150 - val_loss: 0.3201 - val_accuracy: 0.8953
#
# Epoch 00065: val_accuracy did not improve from 0.89930
# Epoch 66/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2415 - accuracy: 0.9164 - val_loss: 0.3169 - val_accuracy: 0.8954
#
# Epoch 00066: val_accuracy did not improve from 0.89930
# Epoch 67/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2402 - accuracy: 0.9161 - val_loss: 0.3113 - val_accuracy: 0.8959
#
# Epoch 00067: val_accuracy did not improve from 0.89930
# Epoch 68/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2405 - accuracy: 0.9159 - val_loss: 0.3083 - val_accuracy: 0.8960
#
# Epoch 00068: val_accuracy did not improve from 0.89930
# Epoch 69/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2375 - accuracy: 0.9173 - val_loss: 0.3128 - val_accuracy: 0.8971
#
# Epoch 00069: val_accuracy did not improve from 0.89930
# Epoch 70/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2388 - accuracy: 0.9154 - val_loss: 0.3211 - val_accuracy: 0.8952
#
# Epoch 00070: val_accuracy did not improve from 0.89930
# Epoch 71/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2345 - accuracy: 0.9194 - val_loss: 0.3149 - val_accuracy: 0.8957
#
# Epoch 00071: val_accuracy did not improve from 0.89930
# Epoch 72/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2366 - accuracy: 0.9184 - val_loss: 0.3112 - val_accuracy: 0.8995
#
# Epoch 00072: val_accuracy improved from 0.89930 to 0.89950, saving model to checkpoint_weights/weights.h5
# Epoch 73/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2341 - accuracy: 0.9182 - val_loss: 0.3143 - val_accuracy: 0.8981
#
# Epoch 00073: val_accuracy did not improve from 0.89950
# Epoch 74/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2306 - accuracy: 0.9193 - val_loss: 0.3235 - val_accuracy: 0.8955
#
# Epoch 00074: val_accuracy did not improve from 0.89950
# Epoch 75/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2376 - accuracy: 0.9168 - val_loss: 0.3108 - val_accuracy: 0.8973
#
# Epoch 00075: val_accuracy did not improve from 0.89950
# Epoch 76/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2259 - accuracy: 0.9211 - val_loss: 0.3059 - val_accuracy: 0.8989
#
# Epoch 00076: val_accuracy did not improve from 0.89950
# Epoch 77/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2150 - accuracy: 0.9251 - val_loss: 0.3004 - val_accuracy: 0.8993
#
# Epoch 00077: val_accuracy did not improve from 0.89950
# Epoch 78/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2216 - accuracy: 0.9212 - val_loss: 0.3013 - val_accuracy: 0.9002
#
# Epoch 00078: val_accuracy improved from 0.89950 to 0.90020, saving model to checkpoint_weights/weights.h5
# Epoch 79/300
# 782/782 [==============================] - 65s 83ms/step - loss: 0.2212 - accuracy: 0.9224 - val_loss: 0.3176 - val_accuracy: 0.8985
#
# Epoch 00079: val_accuracy did not improve from 0.90020
# Epoch 80/300
# 782/782 [==============================] - 65s 83ms/step - loss: 0.2200 - accuracy: 0.9226 - val_loss: 0.3046 - val_accuracy: 0.9020
#
# Epoch 00080: val_accuracy improved from 0.90020 to 0.90200, saving model to checkpoint_weights/weights.h5
# Epoch 81/300
# 782/782 [==============================] - 65s 83ms/step - loss: 0.2184 - accuracy: 0.9233 - val_loss: 0.3027 - val_accuracy: 0.9005
#
# Epoch 00081: val_accuracy did not improve from 0.90200
# Epoch 82/300
# 782/782 [==============================] - 65s 83ms/step - loss: 0.2193 - accuracy: 0.9230 - val_loss: 0.3058 - val_accuracy: 0.9019
#
# Epoch 00082: val_accuracy did not improve from 0.90200
# Epoch 83/300
# 782/782 [==============================] - 65s 83ms/step - loss: 0.2196 - accuracy: 0.9236 - val_loss: 0.2968 - val_accuracy: 0.9040
#
# Epoch 00083: val_accuracy improved from 0.90200 to 0.90400, saving model to checkpoint_weights/weights.h5
# Epoch 84/300
# 782/782 [==============================] - 65s 83ms/step - loss: 0.2202 - accuracy: 0.9228 - val_loss: 0.2949 - val_accuracy: 0.9022
#
# Epoch 00084: val_accuracy did not improve from 0.90400
# Epoch 85/300
# 782/782 [==============================] - 65s 83ms/step - loss: 0.2197 - accuracy: 0.9242 - val_loss: 0.3042 - val_accuracy: 0.9023
#
# Epoch 00085: val_accuracy did not improve from 0.90400
# Epoch 86/300
# 782/782 [==============================] - 65s 83ms/step - loss: 0.2155 - accuracy: 0.9245 - val_loss: 0.3046 - val_accuracy: 0.9023
#
# Epoch 00086: val_accuracy did not improve from 0.90400
# Epoch 87/300
# 782/782 [==============================] - 65s 83ms/step - loss: 0.2177 - accuracy: 0.9235 - val_loss: 0.2965 - val_accuracy: 0.9019
#
# Epoch 00087: val_accuracy did not improve from 0.90400
# Epoch 88/300
# 782/782 [==============================] - 65s 83ms/step - loss: 0.2149 - accuracy: 0.9241 - val_loss: 0.3056 - val_accuracy: 0.9036
#
# Epoch 00088: val_accuracy did not improve from 0.90400
# Epoch 89/300
# 782/782 [==============================] - 65s 83ms/step - loss: 0.2172 - accuracy: 0.9252 - val_loss: 0.3016 - val_accuracy: 0.9022
#
# Epoch 00089: val_accuracy did not improve from 0.90400
# Epoch 90/300
# 782/782 [==============================] - 65s 83ms/step - loss: 0.2092 - accuracy: 0.9269 - val_loss: 0.3086 - val_accuracy: 0.9003
#
# Epoch 00090: val_accuracy did not improve from 0.90400
# Epoch 91/300
# 782/782 [==============================] - 65s 83ms/step - loss: 0.2168 - accuracy: 0.9236 - val_loss: 0.3037 - val_accuracy: 0.9037
#
# Epoch 00091: val_accuracy did not improve from 0.90400
# Epoch 92/300
# 782/782 [==============================] - 65s 83ms/step - loss: 0.2149 - accuracy: 0.9256 - val_loss: 0.3033 - val_accuracy: 0.9016
#
# Epoch 00092: val_accuracy did not improve from 0.90400
# Epoch 93/300
# 782/782 [==============================] - 65s 83ms/step - loss: 0.2138 - accuracy: 0.9250 - val_loss: 0.2965 - val_accuracy: 0.9024
#
# Epoch 00093: val_accuracy did not improve from 0.90400
# Epoch 94/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2130 - accuracy: 0.9254 - val_loss: 0.3100 - val_accuracy: 0.8997
#
# Epoch 00094: val_accuracy did not improve from 0.90400
# Epoch 95/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2150 - accuracy: 0.9251 - val_loss: 0.3061 - val_accuracy: 0.9033
#
# Epoch 00095: val_accuracy did not improve from 0.90400
# Epoch 96/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2135 - accuracy: 0.9249 - val_loss: 0.3016 - val_accuracy: 0.9039
#
# Epoch 00096: val_accuracy did not improve from 0.90400
# Epoch 97/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2104 - accuracy: 0.9265 - val_loss: 0.3016 - val_accuracy: 0.9024
#
# Epoch 00097: val_accuracy did not improve from 0.90400
# Epoch 98/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2113 - accuracy: 0.9254 - val_loss: 0.3111 - val_accuracy: 0.9000
#
# Epoch 00098: val_accuracy did not improve from 0.90400
# Epoch 99/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2129 - accuracy: 0.9241 - val_loss: 0.3062 - val_accuracy: 0.8984
#
# Epoch 00099: val_accuracy did not improve from 0.90400
# Epoch 100/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2100 - accuracy: 0.9259 - val_loss: 0.3092 - val_accuracy: 0.8996
#
# Epoch 00100: val_accuracy did not improve from 0.90400
# Epoch 101/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2100 - accuracy: 0.9264 - val_loss: 0.3156 - val_accuracy: 0.9002
#
# Epoch 00101: val_accuracy did not improve from 0.90400
# Epoch 102/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2106 - accuracy: 0.9270 - val_loss: 0.2955 - val_accuracy: 0.9047
#
# Epoch 00102: val_accuracy improved from 0.90400 to 0.90470, saving model to checkpoint_weights/weights.h5
# Epoch 103/300
# 782/782 [==============================] - 65s 83ms/step - loss: 0.2044 - accuracy: 0.9280 - val_loss: 0.3080 - val_accuracy: 0.9027
#
# Epoch 00103: val_accuracy did not improve from 0.90470
# Epoch 104/300
# 782/782 [==============================] - 65s 82ms/step - loss: 0.2078 - accuracy: 0.9265 - val_loss: 0.3068 - val_accuracy: 0.9012
#
# Epoch 00104: val_accuracy did not improve from 0.90470
# Epoch 105/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2074 - accuracy: 0.9262 - val_loss: 0.3105 - val_accuracy: 0.9019
#
# Epoch 00105: val_accuracy did not improve from 0.90470
# Epoch 106/300
# 782/782 [==============================] - 65s 83ms/step - loss: 0.2077 - accuracy: 0.9271 - val_loss: 0.3019 - val_accuracy: 0.9025
#
# Epoch 00106: val_accuracy did not improve from 0.90470
# Epoch 107/300
# 782/782 [==============================] - 65s 83ms/step - loss: 0.2044 - accuracy: 0.9287 - val_loss: 0.3036 - val_accuracy: 0.9043
#
# Epoch 00107: val_accuracy did not improve from 0.90470
# Epoch 108/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2050 - accuracy: 0.9284 - val_loss: 0.3054 - val_accuracy: 0.9002
#
# Epoch 00108: val_accuracy did not improve from 0.90470
# Epoch 109/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2088 - accuracy: 0.9268 - val_loss: 0.3041 - val_accuracy: 0.9027
#
# Epoch 00109: val_accuracy did not improve from 0.90470
# Epoch 110/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2095 - accuracy: 0.9258 - val_loss: 0.3084 - val_accuracy: 0.9024
#
# Epoch 00110: val_accuracy did not improve from 0.90470
# Epoch 111/300
# 782/782 [==============================] - 65s 83ms/step - loss: 0.2052 - accuracy: 0.9288 - val_loss: 0.3008 - val_accuracy: 0.9047
#
# Epoch 00111: val_accuracy did not improve from 0.90470
# Epoch 112/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2063 - accuracy: 0.9272 - val_loss: 0.3048 - val_accuracy: 0.9030
#
# Epoch 00112: val_accuracy did not improve from 0.90470
# Epoch 113/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2091 - accuracy: 0.9271 - val_loss: 0.2962 - val_accuracy: 0.9053
#
# Epoch 00113: val_accuracy improved from 0.90470 to 0.90530, saving model to checkpoint_weights/weights.h5
# Epoch 114/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2097 - accuracy: 0.9255 - val_loss: 0.3027 - val_accuracy: 0.9032
#
# Epoch 00114: val_accuracy did not improve from 0.90530
# Epoch 115/300
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2032 - accuracy: 0.9290 - val_loss: 0.2989 - val_accuracy: 0.9016
#
# Epoch 00115: val_accuracy did not improve from 0.90530
# Epoch 116/300
# 295/782 [==========>...................] - ETA: 37s - loss: 0.2102 - accuracy: 0.9266

# %% [markdown]
# ## As model has saturated, therefore closing the training.
#
# ## Validation accuracy has reached to 0.9
